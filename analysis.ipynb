# %%
import pandas as pd
import numpy as np 

# ======================
# 1. Load Data
# ======================
df=pd.read_csv('sales.csv')
print("\n Original Data:")
df
# Out:
#  Original Data:
#    OrderID Product Region  Units    Price
# 0        1  Laptop   East    2.0  50000.0
# 1        2   Phone   West    3.0  30000.0
# 2        3  Laptop   East    NaN  50000.0
# 3        4  Tablet  North    4.0  20000.0
# 4        5   Phone  South    2.0      NaN
# 5        6  Tablet   West    5.0  20000.0

# %%
# ======================
# 2. Inspect
# ======================

print("\n Data Types:")
print(df.dtypes)

print("\n Missing Values")
print(df.isnull().sum())
# Out:
#  Data Types:
# OrderID      int64
# Product     object
# Region      object
# Units      float64
# Price      float64
# dtype: object
#
#  Missing Values
# OrderID    0
# Product    0
# Region     0
# Units      1
# Price      1
# dtype: int64
